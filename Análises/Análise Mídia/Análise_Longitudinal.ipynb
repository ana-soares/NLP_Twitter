# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)

# %%
pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil) (1.15.0)

# %%
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords 
import re
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import dateutil 
import seaborn as sns
from collections import OrderedDict, Counter
import os
import networkx as nx
import matplotlib.pyplot as plt
from nltk import word_tokenize
import string
from datetime import datetime
import plotly.graph_objs as go
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('/content/drive/My Drive/Projeto Ana/Entrega_v1/Análise_Mídia/mediaframe_export.csv', encoding = 'utf-8')   

df = df.dropna()
#df = df[(df['date'] > '2013-05-01 00:00:00') & (df['date'] < '2013-07-31 09:00:00')]

# %%
def word_transform(words):
    words = words.split()
    total = [x.lower() for x in words]
    manual_list_stop_words = ['só','disse','ser','sobre','ainda','se','além', 'outros','porque','assim','ter', 'access_time', 'more_horiz',
                             'out','jun','publicado','diz','exame','patrocinado','ago','vip','abr','http','vai','HTTP'
                             'jul','jan','abr','set','nov','dez','conteúdo','mar','maio','estadão','marketing','pictwittercom','dia','mil','pra',
                             'fev','paulo', 'the','após', 'redação', 'foto', 'feira', 'segundo', 'nesta', 'sexta','contra','governo','dilma'
            'onde','pode','sábado','segunda','três', 'fazer','todos','parte','local', 'região', 'disse','quarta','nova','novo',
            'via','veja','neste','nm','aponta','mostra','rt','vejaabrilcombr','folha','vai','desde','do','multimidia','vejacom','blog', '-', '@','"','...','dilma']
    stop_words = stopwords.words('portuguese')
    for i in manual_list_stop_words:
        stop_words.append(i)
    
    total = [x for x in total if x not in stop_words]
    total = [re.sub(r'[,\.!?()]', '', x) for x in total]
    total = [x for x in total if not re.search(r"\d", x)]
    
    long_string = (" ").join(total)
    return long_string

# %%
df['text'] = df['text'].apply(word_transform)
#df['tweet'] = df['tweet'].apply(lambda x: x.split())

# %%
df_new = df[['publication_date','text']]
df_new.columns = ['Data','Texto']

# %%
def format_data(x):
  datetime_object = dateutil.parser.parse(x)

  # formatar o datetime para o formato desejado (dia/mês/ano)
  dataFormatada = datetime_object.strftime("%d/%m/%Y")
  return dataFormatada

# %%
df_new['Data'] = df_new['Data'].apply(format_data)
df_new['Data'] = df_new['Data'].apply(lambda x: datetime.strptime(str(x), '%d/%m/%Y'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_period('M'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_timestamp())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_new = df_new.groupby(['Data'])['Texto'].apply(' '.join).reset_index()

# %%
def contar_palavra_corrupcao(row):
    soma = 0
    for i in row.split():
        if i == 'corrupção' or i == 'corrupcao':
            soma+=1
    return soma

def contar_protesto(row):
    soma = 0
    for i in row.split():
        if i == 'protesto':
            soma+=1
    return soma  

def contar_lavajato(row):
    soma = 0
    for i in row.split():
        if i == 'lavajato' or i =='lava jato' or i == 'lava-jato':
            soma+=1
    return soma 

def aprovacao(row):
    soma = 0
    for i in row.split():
        if i == 'aprovação':
            soma+=1
    return soma 

def pesquisa(row):
    soma = 0
    for i in row.split():
        if i == 'pesquisa':
            soma+=1
    return soma 

def ibope(row):
    soma = 0
    for i in row.split():
        if i == 'ibope':
            soma+=1
    return soma 

def dilma(row):
    soma = 0
    for i in row.split():
        if i == 'dilma':
            soma+=1
    return soma 

def lula(row):
    soma = 0
    for i in row.split():
        if i == 'lula':
            soma+=1
    return soma 

def datafolha(row):
    soma = 0
    for i in row.split():
        if i == 'datafolha':
            soma+=1
    return soma 

def brasil(row):
    soma = 0
    for i in row.split():
        if i == 'brasil':
            soma+=1
    return soma

# %%
df_new['coorupcao_freq'] = df_new['Texto'].apply(contar_palavra_corrupcao)
df_new['protesto_freq'] = df_new['Texto'].apply(contar_protesto)
df_new['lavajato_freq'] = df_new['Texto'].apply(contar_lavajato)
df_new['aprovacao'] = df_new['Texto'].apply(aprovacao)
df_new['pesquisa'] = df_new['Texto'].apply(pesquisa)
df_new['ibope'] = df_new['Texto'].apply(ibope)
df_new['dilma'] = df_new['Texto'].apply(dilma)
df_new['lula'] = df_new['Texto'].apply(lula)
df_new['datafolha'] = df_new['Texto'].apply(datafolha)
df_new['brasil'] = df_new['Texto'].apply(brasil)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['coorupcao_freq'], name = 'Corrupção'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['protesto_freq'], name = 'Protesto'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['aprovacao'], name = 'Aprovação'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['lavajato_freq'], name = 'Lava jato'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['pesquisa'], name = 'pesquisa'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['ibope'], name = 'ibope'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['dilma'], name = 'dilma'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['lula'], name = 'lula'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['datafolha'], name = 'datafolha'))
fig.add_trace(go.Scatter(x=df_new['Data'], y=df_new['brasil'], name = 'brasil'))
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3a2c79a9-f1a9-4eec-81c4-3ed1c71c037c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a2c79a9-f1a9-4eec-81c4-3ed1c71c037c")) {
#                     Plotly.newPlot(
#                         '3a2c79a9-f1a9-4eec-81c4-3ed1c71c037c',
#                         [{"name": "Corrup\u00e7\u00e3o", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [71, 40, 58, 44, 36, 109, 121, 104, 109, 59, 97, 77, 55, 57, 63, 125, 76, 103, 81, 83, 203, 351, 320, 288, 207, 277, 765, 501, 176, 233, 355, 346, 263, 254, 268, 254, 191, 162, 679, 410, 371, 181, 111, 150, 194, 121, 155, 105]}, {"name": "Protesto", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [5, 5, 9, 15, 2, 64, 33, 11, 11, 30, 8, 6, 9, 25, 9, 7, 15, 32, 8, 6, 8, 9, 12, 9, 12, 10, 363, 245, 32, 15, 18, 325, 42, 29, 77, 206, 22, 21, 922, 87, 85, 25, 39, 20, 32, 7, 5, 4]}, {"name": "Aprova\u00e7\u00e3o", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [24, 13, 61, 42, 35, 87, 140, 129, 54, 46, 51, 108, 17, 73, 124, 88, 39,  ...

# %% [markdown]
# #### Longitudinal quantidade Tweets

# %%
df = pd.read_csv('/content/drive/My Drive/Projeto Ana/Entrega_v1/Análise_Mídia/mediaframe_export.csv', encoding = 'utf-8')   

df = df.dropna()
#df = df[(df['date'] > '2013-05-01 00:00:00') & (df['date'] < '2013-07-31 09:00:00')]

# %%
df_new = df[['publication_date']]
df_new.columns = ['Data']
df_new['count'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def format_data(x):
  datetime_object = dateutil.parser.parse(x)

  # formatar o datetime para o formato desejado (dia/mês/ano)
  dataFormatada = datetime_object.strftime("%d/%m/%Y")
  return dataFormatada

# %%
df_new['Data'] = df_new['Data'].apply(format_data)
df_new['Data'] = df_new['Data'].apply(lambda x: datetime.strptime(str(x), '%d/%m/%Y'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_period('M'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_timestamp())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_long = df_new.groupby(['Data'])['count'].sum().reset_index()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_long['Data'], y=df_long['count'], name = 'Quantidade de Tweets'))
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="df31d721-241e-41ac-8939-c196617de2c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("df31d721-241e-41ac-8939-c196617de2c6")) {
#                     Plotly.newPlot(
#                         'df31d721-241e-41ac-8939-c196617de2c6',
#                         [{"name": "Quantidade de Tweets", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [116, 102, 205, 149, 144, 281, 346, 237, 319, 344, 255, 262, 231, 317, 338, 322, 286, 301, 293, 369, 452, 550, 362, 303, 317, 284, 623, 468, 369, 417, 497, 584, 439, 461, 333, 471, 243, 257, 1330, 698, 871, 393, 302, 305, 280, 224, 138, 149]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ### Sentimento

# %%
df = pd.read_csv('/content/drive/My Drive/Projeto Ana/Entrega_v1/Análise_Mídia/mediaframe_export.csv', encoding = 'utf-8')   

df = df.dropna()
#df = df[(df['date'] > '2013-05-01 00:00:00') & (df['date'] < '2013-07-31 09:00:00')]

# %%
def word_transform(words):
    words = words.split()
    total = [x.lower() for x in words]
    manual_list_stop_words = ['só','disse','ser','sobre','ainda','se','além', 'outros','porque','assim','ter', 'access_time', 'more_horiz',
                             'out','jun','publicado','diz','exame','patrocinado','ago','vip','abr','http','vai','HTTP'
                             'jul','jan','abr','set','nov','dez','conteúdo','mar','maio','estadão','marketing','pictwittercom','dia','mil','pra',
                             'fev','paulo', 'the','após', 'redação', 'foto', 'feira', 'segundo', 'nesta', 'sexta','contra','governo','dilma'
            'onde','pode','sábado','segunda','três', 'fazer','todos','parte','local', 'região', 'disse','quarta','nova','novo',
            'via','veja','neste','nm','aponta','mostra','rt','vejaabrilcombr','folha','vai','desde','do','multimidia','vejacom','blog', '-', '@','"','...','dilma']
    stop_words = stopwords.words('portuguese')
    for i in manual_list_stop_words:
        stop_words.append(i)
    
    total = [x for x in total if x not in stop_words]
    total = [re.sub(r'[,\.!?()]', '', x) for x in total]
    total = [x for x in total if not re.search(r"\d", x)]
    
    long_string = (" ").join(total)
    return long_string

# %%
df['text'] = df['text'].apply(word_transform)
#df['tweet'] = df['tweet'].apply(lambda x: x.split())

# %%
df['text'] = df['text'].apply(lambda x: x.split())

# %%
df_new = df[['publication_date','text']]
df_new.columns = ['Data','Texto']
df_new['count'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def format_data(x):
  datetime_object = dateutil.parser.parse(x)

  # formatar o datetime para o formato desejado (dia/mês/ano)
  dataFormatada = datetime_object.strftime("%d/%m/%Y")
  return dataFormatada

# %%
df_new['Data'] = df_new['Data'].apply(format_data)
df_new['Data'] = df_new['Data'].apply(lambda x: datetime.strptime(str(x), '%d/%m/%Y'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_period('M'))
df_new['Data'] = df_new['Data'].apply(lambda x: x.to_timestamp())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pol = pd.read_csv('/content/drive/My Drive/Projeto Ana/Utils/Análise 2020/oplexicon_v3.0/lexico_v3.0.txt', skiprows=500, encoding = 'utf-8',usecols=[0,2])
df_pol.columns = ['palavra','polaridade']

lista_positivas = df_pol[df_pol['polaridade'] > 0]['palavra'].values.tolist()
lista_negativas = df_pol[df_pol['polaridade'] < 0]['palavra'].values.tolist()

# %%
def count_positivo(x, lista_positivas):

  number_set = len(set(x).intersection(lista_positivas)) 
  return number_set

def count_negativo(x, lista_negativas):
  number_set = len(set(x).intersection(lista_negativas)) 
  return number_set

# %%
# %%time
df_new['positivo_qtd'] = df_new['Texto'].apply(lambda x: count_positivo(x,lista_positivas=lista_positivas))
# Out:
# CPU times: user 4.59 s, sys: 760 µs, total: 4.59 s
# Wall time: 4.6 s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# %%time
df_new['negativo_qtd'] = df_new['Texto'].apply(lambda x: count_negativo(x,lista_negativas=lista_negativas))
# Out:
# CPU times: user 6.42 s, sys: 2.75 ms, total: 6.42 s
# Wall time: 6.43 s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_new['positivo'] = df_new['positivo_qtd'] - df_new['negativo_qtd']
df_new['negativo'] = df_new['negativo_qtd'] - df_new['positivo_qtd']

# %%
def new(x):
  if x > 0:
    return 1
  else:
    return 0

df_new['positivo'] = df_new['positivo'].apply(new)
df_new['negativo'] = df_new['negativo'].apply(new)

# %%
df_new_pol = df_new[['Data','count','positivo','negativo']]

# %%
df_long = df_new.groupby(['Data'])['count','positivo','negativo'].sum().reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_long['Data'], y=df_long['positivo'], name = 'Notícias Positivas'))
fig.add_trace(go.Scatter(x=df_long['Data'], y=df_long['negativo'], name = 'Notícias Negativas'))
fig.add_trace(go.Scatter(x=df_long['Data'], y=df_long['count'], name = 'Quantidade de Notícias'))
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d7ebf190-529c-4625-8035-798922ae4fcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d7ebf190-529c-4625-8035-798922ae4fcc")) {
#                     Plotly.newPlot(
#                         'd7ebf190-529c-4625-8035-798922ae4fcc',
#                         [{"name": "Not\u00edcias Positivas", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [60, 54, 128, 82, 83, 148, 193, 150, 175, 207, 146, 143, 119, 152, 178, 158, 145, 170, 154, 201, 224, 317, 215, 167, 168, 142, 325, 260, 202, 220, 251, 328, 219, 253, 153, 282, 138, 130, 790, 423, 497, 209, 183, 156, 142, 124, 80, 88]}, {"name": "Not\u00edcias Negativas", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00"], "y": [45, 39, 58, 60, 51, 114, 127, 71, 111, 106, 94, 102, 93, 139, 126, 131, 114, 115, 124, 137, 201, 196, 120, 103, 129, 112, 232, 161, 141, 162, 214, 219, 183, 174, 154, 149, 91, 107, 439, 222, 308, 149, 102, 119, 117, 85, 48, 54]}, {"name": "Quantidade de Not\u00edcias", "type": "scatter", "x": ["2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:0 ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.88888888888888

# %%
df_new
# Out:
#             Data  ... negativo_qtd
# 0     2015-03-01  ...           10
# 1     2016-03-01  ...            9
# 2     2016-03-01  ...           14
# 3     2014-11-01  ...          144
# 4     2016-03-01  ...           11
# ...          ...  ...          ...
# 17365 2015-06-01  ...           28
# 17366 2015-08-01  ...           16
# 17367 2015-12-01  ...           23
# 17368 2015-09-01  ...            8
# 17369 2015-09-01  ...           22
#
# [17337 rows x 5 columns]

# %%
lista_positivas
# Out:
# ['#w00t',
#  '#win',
#  '#windows',
#  '#windowsphonemango',
#  '#winning',
#  '#wp7',
#  '#zegotinha',
#  'ababelar-se',
#  'abaçanar',
#  'abacinar',
#  'abalançado',
#  'abalançar',
#  'abalizada',
#  'abalizadas',
#  'abalizado',
#  'abalizados',
#  'abalroar-se',
#  'abandalhar',
#  'abarbar',
#  'abarbarado',
#  'abarregar',
#  'abastada',
#  'abastadas',
#  'abastadear',
#  'abastado',
#  'abastados',
#  'abastardar',
#  'abastardar-se',
#  'abastardear-se',
#  'abastecer',
#  'abastoso',
#  'abatocar',
#  'abduzir-se',
#  'abeirar-se',
#  'abençoada',
#  'abençoadas',
#  'abençoado',
#  'abençoados',
#  'aberratório',
#  'abertão',
#  'abiselar',
#  'abismar',
#  'abjugar-se',
#  'abjurar',
#  'ablegar',
#  'ablegar-se',
#  'abnegada',
#  'abnegadas',
#  'abnegado',
#  'abnegados',
#  'abnegar',
#  'abnoitar',
#  'abnormal',
#  'abnóxio',
#  'abnuir',
#  'abobalhar',
#  'abolorecer',
#  'abolorentar',
#  'abolsar',
#  'abonada',
#  'abonadas',
#  'abonado',
#  'abonados',
#  'abonançar-se',
#  'abonatória',
#  'abonatórias',
#  'abonatório',
#  'abonatórios',
#  'aborrecer-se',
#  'abraçada',
#  'abracadabrante',
#  'abracadábrico',
#  'abraçadas',
#  'abraçado',
#  'abraçados',
#  'abraçar-se',
#  'abrancar',
#  'abrandar-se',
#  'abrangente',
#  'abrangentes',
#  'abrasar-se',
#  'abrejar',
#  'abrilhantada',
#  'abrilhantadas',
#  'abrilhantado',
#  'abrilhantados',
#  'abrir o possibilidade de',
#  'abrutalhar',
#  'abrutar',
#  'abscidar-se',
#  'absoluta',
#  'absolutas',
#  'absoluto',
#  'absolutos',
#  'absorvente',
#  'absorventes',
#  'absorver-se',
#  'abstémia',
#  'abstémias',
#  'abstémica',
#  'abstémicas',
#  'abstémico',
#  'abstémicos',
#  'abstémio',
#  'abstémios',
#  'abstrair',
#  'abugalhar',
#  'abundante',
#  'abundar',
#  'abundoso',
#  'aburacar',
#  'abusar',
#  'abuzinar',
#  'acabamento',
#  'açacalado',
#  'acaçapar',
#  'acachar',
#  'acafelar',
#  'acalentar-se',
#  'acalmar-se',
#  'acalorar',
#  'acalorar-se',
#  'acamar',
#  'acanalhar',
#  'acapelado',
#  'acarar',
#  'acarear',
#  'acarinhar',
#  'acarpetar',
#  'acarrar',
#  'acarrear',
#  'acarretar',
#  'acasalar',
#  'acastelar',
#  'acatada',
#  'acatadas',
#  'acatado',
#  'acatados',
#  'acavalar',
#  'aceder',
#  'aceirar',
#  'aceita',
#  'aceitar',
#  'aceitas',
#  'aceitáveis',
#  'aceitável',
#  'aceito',
#  'aceitos',
#  'acenar',
#  'acender-se',
#  'acentuar',
#  'acerar',
#  'aceroso',
#  'acertada',
#  'acertadas',
#  'acertado',
#  'acertados',
#  'aceso',
#  'acessíveis',
#  'acessível',
#  'achanar',
#  'achar',
#  'achar-se',
#  'achegada',
#  'achegadas',
#  'achegado',
#  'achegados',
#  'achegar-se',
#  'acicalado',
#  'acidentar',
#  'acidificar',
#  'acionar',
#  'acirrada',
#  'aclarado',
#  'aclarar-se',
#  'aclimar',
#  'aclimar-se',
#  'aclimatar',
#  'aclimatar-se',
#  'aclimatizar',
#  'aclimatizar-se',
#  'acobardar',
#  'acocar',
#  'acogular',
#  'acolchoar',
#  'acolhedor',
#  'acolhedora',
#  'acolhedoras',
#  'acolhedores',
#  'acomodar',
#  'acomodar-se',
#  'acômodo',
#  'acompanhável',
#  'acomunar-se',
#  'aconchavar-se',
#  'aconchegada',
#  'aconchegadas',
#  'aconchegado',
#  'aconchegados',
#  'aconchegante',
#  'aconchegar-se',
#  'acondicionar',
#  'acondicionar-se',
#  'acondimentar',
#  'aconselhar-se',
#  'açorado',
#  'acordar',
#  'acorde',
#  'acordes',
#  'acoroçoar-se',
#  'acorrentar',
#  'acorrentar-se',
#  'acostumar',
#  'acostumar-se',
#  'acotar',
#  'acouçar',
#  'acovardar',
#  'acreditada',
#  'acreditadas',
#  'acreditado',
#  'acreditados',
#  'acrescentada',
#  'acrescentadas',
#  'acrescentado',
#  'acrescentados',
#  'acrescentar',
#  'acrescer',
#  'acrimoniar',
#  'activa',
#  'activas',
#  'activo',
#  'activos',
#  'acuminado',
#  'acurada',
#  'acuradas',
#  'acurado',
#  'acurados',
#  'adaptar-se',
#  'adaptáveis',
#  'adaptável',
#  'adargar',
#  'adentrar',
#  'adepta',
#  'adeptas',
#  'adepto',
#  'adeptos',
#  'adequada',
#  'adequadas',
#  'adequado',
#  'adequados',
#  'adequar-se',
#  'adereçado',
#  'aderente',
#  'aderentes',
#  'adergar',
#  'aderir',
#  'adestrada',
#  'adestradas',
#  'adestrado',
#  'adestrados',
#  'adestrar',
#  'adeusar',
#  'adicionado',
#  'adicionar',
#  'adicta',
#  'adictas',
#  'adicto',
#  'adictos',
#  'adinheirado',
#  'adir',
#  'aditado',
#  'aditar',
#  'adivinhar',
#  'adjacentes',
#  'adjugar',
#  'adminicular',
#  'administrador',
#  'administradora',
#  'administradoras',
#  'administradores',
#  'admirar',
#  'admirar-se',
#  'admiráveis',
#  'admirável',
#  'admitir',
#  'adnumerar',
#  'adoidar',
#  'adomesticar',
#  'adorada',
#  'adoradas',
#  'adorado',
#  'adorados',
#  'adoranda',
#  'adorandas',
#  'adorando',
#  'adorandos',
#  'adorar',
#  'adoráveis',
#  'adorável',
#  'adoudar',
#  'adoutrinar',
#  'adregar',
#  'adscrito',
#  'adubada',
#  'adubadas',
#  'adubado',
#  'adubados',
#  'adubar',
#  'adular',
#  'adulterar-se',
#  'adumbrar',
#  'adunar',
#  'adunar-se',
#  'aduzir',
#  'adverbar',
#  'adversar',
#  'afagar',
#  'afainado',
#  'afamada',
#  'afamadas',
#  'afamado',
#  'afamados',
#  'afamar-se',
#  'afaquear',
#  'afarelar',
#  'afastadas',
#  'afatiar',
#  'afáveis',
#  'afável',
#  'afazer',
#  'afazer-se',
#  'afectiva',
#  'afectivas',
#  'afectivo',
#  'afectivos',
#  'afectuosa',
#  'afectuosas',
#  'afectuoso',
#  'afectuosos',
#  'afeiar',
#  'afeiçoada',
#  'afeiçoadas',
#  'afeiçoado',
#  'afeiçoados',
#  'afeiçoar-se',
#  'aferrenhar-se',
#  'afervorar-se',
#  'afetiva',
#  'afetivas',
#  'afetível',
#  'afetivo',
#  'afetivos',
#  'afetuar-se',
#  'afetuosa',
#  'afetuosas',
#  'afetuoso',
#  'afetuosos',
#  'afigurar',
#  'afinada',
#  'afinadas',
#  'afinado',
#  'afinados',
#  'afinar',
#  'afinar',
#  'afincar-se',
#  'afirmar',
#  'afirmativa',
#  'afirmativas',
#  'afirmativo',
#  'afirmativos',
#  'afixa',
#  'afixas',
#  'afixo',
#  'afixos',
#  'aflar',
#  'afleumar',
#  'afluente',
#  'afluentes',
#  'afluir',
#  'afofar',
#  'afogar-se',
#  'afoguear-se',
#  'aformoseado',
#  'afortalecer',
#  'afortalezar',
#  'afortunada',
#  'afortunadas',
#  'afortunado',
#  'afortunados',
#  'afouto',
#  'afrescar',
#  'africanos',
#  'afroixar-se',
#  'afuleimar',
#  'afumear',
#  'afumegar',
#  'afundar',
#  'afunilado',
#  'afuroar',
#  'afutricar',
#  'afuzilar',
#  'agalanado',
#  'agarrar-se',
#  'agéis',
#  'agermanar',
#  'agermanar-se',
#  'agigantar',
#  'agigantear',
#  'ágil',
#  'agir',
#  'agitar',
#  'aglomerar-se',
#  'agoirar',
#  'agourar',
#  'agradada',
#  'agradadas',
#  'agradado',
#  'agradados',
#  'agradar',
#  'agradar-se',
#  'agradáveis',
#  'agradável',
#  'agravante',
#  'agravar-se',
#  'agregar',
#  'agregar-se',
#  'agremiar-se',
#  'agrupar-se',
#  'aguar',
#  'agüentar-se',
#  'airosa',
#  'airosas',
#  'airoso',
#  'airosos',
#  'ajaezado',
#  'ajeitar',
#  'ajeitar-se',
#  'ajoujar-se',
#  'ajudada',
#  'ajudadas',
#  'ajudado',
#  'ajudados',
#  'ajuizada',
#  'ajuizadas',
#  'ajuizado',
#  'ajuizados',
#  'ajuizar',
#  'ajuizar-se',
#  'ajuntado',
#  'ajuntar',
#  'ajuntar-se',
#  'ajustar',
#  'ajustar-se',
#  'alabastrino',
#  'álacre',
#  'alada',
#  'aladas',
#  'alado',
#  'alados',
#  'alargar-se',
#  'alarmar',
#  'alastrar-se',
#  'alcagüetar',
#  'alçar-se',
#  'alcatifar',
#  'alcofar',
#  'alcoolizar',
#  'alcoolizar-se',
#  'alcovetar',
#  'alcovitar',
#  'alegrar-se',
#  'alegre',
#  'alegres',
#  'aleijar-se',
#  'alentada',
#  'alentadas',
#  'alentado',
#  'alentador',
#  'alentadora',
#  'alentadoras',
#  'alentadores',
#  'alentados',
#  'alentar',
#  'alentoso',
#  'alerta',
#  'alertar',
#  'alertas',
#  'alevantar',
#  'alfaiado',
#  'alfombrar',
#  'algemar-se',
#  'aliada',
#  'aliançar-se',
#  'aliar-se',
#  'alicerçada',
#  'alicerçadas',
#  'alicerçado',
#  'alicerçados',
#  'alicerçar',
#  'alicerçar-se',
#  'alienados',
#  'alienar',
#  'alindado',
#  'alinhada',
#  'alinhadas',
#  'alinhado',
#  'alinhados',
#  'alinhavar',
#  'alisar',
#  'alistar',
#  'alivelar',
#  'aliviar-se',
#  'alma',
#  'almas',
#  'almejar',
#  'almiscarado',
#  'almo',
#  'almofadar',
#  'almos',
#  'alongar-se',
#  'alonginquar-se',
#  'aloucar',
#  'altamente',
#  'altamentes',
#  'altanado',
#  'altear-se',
#  'altitonante',
#  'alto-astral',
#  'altruísta',
#  'altruístas',
#  'altruística',
#  'altruísticas',
#  'altruístico',
#  'altruísticos',
#  'altura',
#  'alucinante',
#  'alucinantes',
#  'alucinógenas',
#  'alugar',
#  'alumbrar-se',
#  'alumiada',
#  'alumiadas',
#  'alumiado',
#  'alumiados',
#  'alumiar-se',
#  'alva',
#  'alvas',
#  'alvear',
#  'alvejar',
#  'alvescer',
#  'alvinitente',
#  'alvíssima',
#  'alvíssimas',
#  'alvíssimo',
#  'alvíssimos',
#  'alvo',
#  'alvos',
#  'amacacar',
#  'amada',
#  'amadas',
#  'amado',
#  'amados',
#  'amadurecida',
#  'amadurecidas',
#  'amadurecido',
#  'amadurecidos',
#  'amaestrar',
#  'amainar-se',
#  'amaldiçoar',
#  'amalgamar-se',
#  'amalucada',
#  'amancebar',
#  'amansar-se',
#  'amante',
#  'amantes',
#  'amar',
#  'amarfanhar-se',
#  'amasiar',
#  'amáveis',
#  'amável',
#  'ambicionar',
#  'ambreado',
#  'ambrosíaco',
#  'ambrosiado',
#  'ameaçadora',
#  'ameaçadores',
#  'ameaçar',
#  'amedrontar',
#  'ameigar-se',
#  'amelindrar-se',
#  'amena',
#  'amenas',
#  'amenizar-se',
#  'ameno',
#  'amenos',
#  'amenoso',
#  'amesendar-se',
#  'amestrada',
#  'amestradas',
#  'amestrado',
#  'amestrados',
#  'amestrar',
#  'amiga',
#  'amigalhaça',
#  'amigalhaças',
#  'amigalhaço',
#  'amigalhaços',
#  'amigalhão',
#  'amigalhões',
#  'amigalhona',
#  'amigalhonas',
#  'amigar',
#  'amigas',
#  'amigáveis',
#  'amigável',
#  'amigo',
#  'amigos',
#  'amigueiro',
#  'amimar',
#  'amistosa',
#  'amistosas',
#  'amistoso',
#  'amistosos',
#  'amodelar',
#  'amoderar',
#  'amoedado',
#  'amoitar',
#  'amoldar-se',
#  'amoldurar-se',
#  'amolentar',
#  'amolestar-se',
#  'amoral',
#  'amoráveis',
#  'amorável',
#  'amorenar-se',
#  'amorosa',
#  'amorosas',
#  'amoroso',
#  'amorosos',
#  'amorsegar',
#  'amortecer-se',
#  'amortiçar-se',
#  'amoutar',
#  'ampla',
#  'amplas',
#  'amplo',
#  'amplos',
#  'amulatar-se',
#  'anacarar-se',
#  'anacrônico',
#  'analisar',
#  'anarquista',
#  'ancorar',
#  'andar',
#  'anediar',
#  'anelar',
#  'angélica',
#  'angelicais',
#  'angelical',
#  'angélicas',
#  'angélico',
#  'angélicos',
#  'angustiantes',
#  'animada',
#  'animadas',
#  'animado',
#  'animador',
#  'animadora',
#  'animadoras',
#  'animadores',
#  'animados',
#  'animalizar',
#  'animar-se',
#  'animosa',
#  'animosas',
#  'animoso',
#  'animosos',
#  'aninhar',
#  'anivelar',
#  'anoitar',
#  'anoitecer',
#  'anomálico',
#  'anômalo',
#  'anortear',
#  'ansiar',
#  'ante-sentir',
#  'antecipar',
#  'antedizer',
#  'anteferir',
#  'antemurado',
#  'antenada',
#  'antenadas',
#  'antenado',
#  'antenados',
#  'antidogmática',
#  'antidogmáticas',
#  'antidogmático',
#  'antidogmáticos',
#  'antifascista',
#  'antifascistas',
#  'antigênico',
#  'antinazista',
#  'antinazistas',
#  'antojar',
#  'antolhar',
#  'antologiar',
#  'antológico',
#  'antropológica',
#  'anuir',
#  'anuviar',
#  'apacificar-se',
#  'apagadas',
#  'apagar-se',
#  'apaixonadinha',
#  'apaixonante',
#  'apaixonantes',
#  'apajear',
#  'apalavrar',
#  'apalavrar-se',
#  'apanhar-se',
#  'apaparicar',
#  'aparado',
#  'aparamentado',
#  'aparato',
#  'aparatoso',
#  'aparceirar-se',
#  'aparvalhar',
#  'aparvoar',
#  'apascentar',
#  'apatetar',
#  'apavesar-se',
#  'apavonar',
#  'apavonar-se',
#  'apavorada',
#  'apavorar',
#  'apavorizar',
#  'apaziguador',
#  'apaziguadora',
#  'apaziguadoras',
#  'apaziguadores',
#  'apaziguar',
#  'apaziguar-se',
#  'apedrar',
#  'apedrar',
#  'apedrejar',
#  'apedrejar',
#  'apegar',
#  'apegar-se',
#  'apejar-se',
#  'apelar',
#  'apelidar',
#  'apenar',
#  'apepinar',
#  'aperfeiçoamento',
#  'aperrar',
#  'aperrear-se',
#  'aperuar',
#  'apessoada',
#  'apessoadas',
#  'apessoado',
#  'apessoados',
#  'apetecedor',
#  'apetecer',
#  'apetitar',
#  'apetitivo',
#  'apimentar',
#  'apinhar-se',
#  'apitar',
#  'aplacar-se',
#  'aplaudir',
#  'aplaudir-se',
#  'aplicada',
#  'aplicadas',
#  'aplicado',
#  'aplicados',
#  'apodar',
#  'apoderada',
#  'apoderadas',
#  'apoderado',
#  'apoderados',
#  'apodrentar',
#  'apoiador ',
#  'apoiadora',
#  'apoiadoras',
#  'apoiadores',
#  'apoiar',
#  'apoiar-se',
#  'apojar',
#  'apolínea',
#  'apolíneas',
#  'apolíneo',
#  'apolíneos',
#  'apologista',
#  'apologistas',
#  'apontear',
#  'apoquentar-se',
#  'apor',
#  'aposentar-se',
#  'aposta',
#  'apostada',
#  'apostadas',
#  'apostado',
#  'apostados',
#  'apostar',
#  'apostar-se',
#  'apostas',
#  'apostasiar',
#  'apostatar',
#  'aposto',
#  'apostos',
#  'apoteosar',
#  'apoteotizar',
#  'aprazenteiro',
#  'aprazer',
#  'aprazer-se',
#  'aprazerado',
#  'aprazíveis',
#  'aprazível',
#  'apreciada',
#  'apreciadas',
#  'apreciado',
#  'apreciador',
#  'apreciadora',
#  'apreciadoras',
#  'apreciadores',
#  'apreciados',
#  'apreciar',
#  'apreciáveis',
#  'apreciável',
#  'apreensivos',
#  'apresentar-se',
#  'apresentáveis',
#  'apresentável',
#  'aprimorada',
#  'aprimoradas',
#  'aprimorado',
#  'aprimorados',
#  'aprochegar-se',
#  'aprofundada',
#  'aprofundadas',
#  'aprofundado',
#  'aprofundados',
#  'apropositado',
#  'apropriada',
#  'apropriadas',
#  'apropriado',
#  'apropriados',
#  'aprovada',
#  'aprovadas',
#  'aprovado',
#  'aprovados',
#  'aprovar',
#  'aproveitáveis',
#  'aproveitável',
#  'aprovisionar',
#  'aprumada',
#  'aprumadas',
#  'aprumado',
#  'aprumados',
#  'apta',
#  'aptas',
#  'apto',
#  'aptos',
#  'apuado',
#  'apunhar',
#  'apurada',
#  'apuradas',
#  'apurado',
#  'apurados',
#  'apurar',
#  'aquecido',
#  'aquedar',
#  'aqueixar-se',
#  'aquiescer',
#  'aquietar',
#  'aquietar-se',
#  'aquilatar',
#  'arcaboiçar',
#  'arcabouçar',
#  'ardejar',
#  'ardente',
#  'ardentes',
#  'arder',
#  'ardida',
#  'ardidas',
#  'ardido',
#  'ardidos',
#  'ardidoso',
#  'árduo',
#  'arear',
#  'arfar',
#  'ariscar',
#  'aristocrática',
#  'aristocráticas',
#  'aristocrático',
#  'aristocráticos',
#  'armar',
#  'arnaz',
#  'arnazes',
#  'aromado',
#  'aromal',
#  'aromático',
#  'aromatizado',
#  'aromoso',
#  'arquejar',
#  'arqueológico',
#  'arquitetar',
#  'arraigar-se',
#  'arralar',
#  'arralentar',
#  'arranjada',
#  'arranjadas',
#  'arranjado',
#  'arranjados',
#  'arranjar',
#  'arranjar-se',
#  'arrasador',
#  'arrazoada',
#  'arrazoadas',
#  'arrazoado',
#  'arrazoados',
#  'arrazoar',
#  'arreado',
#  'arrebanhar',
#  'arrebanhar-se',
#  'arrebatador',
#  'arrebatadora',
#  'arrebatadoras',
#  'arrebatadores',
#  'arrecadar',
#  'arrefeçar',
#  'arrefecer',
#  'arrefecer-se',
#  'arrefentar',
#  'arregalar',
#  'arregoar',
#  'arreliar-se',
#  'arremate',
#  'arremedar',
#  'arremenicar',
#  'arremessar',
#  'arremeter',
#  'arrendador',
#  'arrepelar-se',
#  'arrepiar',
#  'arretada',
#  'arretadas',
#  'arretado',
#  'arretados',
#  'arrijar',
#  'arrimar',
#  'arrimar-se',
#  'arrojada',
#  'arrojadas',
#  'arrojadiço',
#  'arrojado',
#  'arrojados',
#  'arrojar',
#  'arrolhar',
#  'arrotear',
#  'arroubar',
#  'arrufar',
#  'arruinador',
#  'arrumada',
#  'arrumadas',
#  'arrumado',
#  'arrumados',
#  'arrumar-se',
#  'arrupiar',
#  'articular-se',
#  'artifícios',
#  'artística',
#  'artísticas',
#  'artístico',
#  'artísticos',
#  'ascendente',
#  'asiático',
#  'aspar',
#  'aspiração',
#  'aspirar',
#  'asquatro',
#  'assalariar',
#  'assassinada',
#  'assassinadas',
#  'assassinado',
#  'assassinados',
#  'assassino',
#  'asseada',
#  'asseadas',
#  'asseado',
#  'asseados',
#  'assegurada',
#  'asseguradas',
#  'assegurado',
#  'assegurados',
#  'assegurar',
#  'assegurar-se',
#  'asselvajar',
#  'assentada',
#  'assentadas',
#  ...]
